# %%
# Instala la herramienta Consola del archivo ISIC
# !pip install isic-cli #Sacada desde el repositorio de Github https://github.com/ImageMarkup/isic-cli/blob/master/README.md

# Se actualizan las librerías a versiones compatibles para resolver los conflictos.
# !pip install tensorflow==2.19.0
# Out:
# Collecting isic-cli
#   Downloading isic_cli-12.4.0-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: click>=8.2.0 in /usr/local/lib/python3.12/dist-packages (from isic-cli) (8.3.0)
# Collecting django-s3-file-field-client>=1.0.0 (from isic-cli)
#   Downloading django_s3_file_field_client-1.1.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting girder-cli-oauth-client<1.0.0 (from isic-cli)
#   Downloading girder_cli_oauth_client-0.4.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: humanize in /usr/local/lib/python3.12/dist-packages (from isic-cli) (4.13.0)
# Collecting isic-metadata>=1.2.0 (from isic-cli)
#   Downloading isic_metadata-4.11.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.12/dist-packages (from isic-cli) (10.8.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from isic-cli) (25.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from isic-cli) (2.32.4)
# Collecting retryable-requests (from isic-cli)
#   Downloading retryable_requests-0.1.2-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from isic-cli) (13.9.4)
# Requirement already satisfied: sentry-sdk in /usr/local/lib/python3.12/dist-packages (from isic-cli) (2.40.0)
# Requirement already satisfied: tenacity in /usr/local/lib/python3.12/dist-packages (from isic-cli) (8.5.0)
# Requirement already satisfied: authlib in /usr/local/lib/python3.12/dist-packages (from girder-cli-oauth-client<1.0.0->isic-cli) (1.6.5)
# Collecting pyxdg (from girder-cli-oauth-client<1.0.0->isic-cli)
#   Downloading pyxdg-0.28-py2.py3-none-any.whl.metadata (567 bytes)
# Requirement already satisfied: pydantic>=2.4 in /usr/local/lib/python3.12/dist-packages (from isic-metadata>=1.2.0->isic-cli) (2.11.10)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->isic-cli) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->isic-cli) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->isic-cli) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->isic-cli) (2025.10.5)
# Requirement already satisfied: requests-toolbelt in /usr/local/lib/python3.12/dist-packages (from retryable-requests->isic-cli) (1.0.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->isic-cli) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->isic-cli) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->isic-cli) (0.1.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.4->isic-metadata>=1.2.0->isic-cli) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.4->isic-metadata>=1.2.0->isic-cli) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.4->isic-metadata>=1.2.0->isic-cli) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.4->isic-metadata>=1.2.0->isic-cli) (0.4.2)
# Requirement already satisfied: cryptography in /usr/local/lib/python3.12/dist-packages (from authlib->girder-cli-oauth-client<1.0.0->isic-cli) (43.0.3)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography->authlib->girder-cli-oauth-client<1.0.0->isic-cli) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography->authlib->girder-cli-oauth-client<1.0.0->isic-cli) (2.23)
# Downloading isic_cli-12.4.0-py3-none-any.whl (34 kB)
# Downloading django_s3_file_field_client-1.1.0-py3-none-any.whl (3.2 kB)
# Downloading girder_cli_oauth_client-0.4.0-py3-none-any.whl (8.1 kB)
# Downloading isic_metadata-4.11.0-py3-none-any.whl (27 kB)
# Downloading retryable_requests-0.1.2-py3-none-any.whl (7.5 kB)
# Downloading pyxdg-0.28-py2.py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 10.3 MB/s eta 0:00:00
# Installing collected packages: pyxdg, django-s3-file-field-client, retryable-requests, isic-metadata, girder-cli-oauth-client, isic-cli
# Successfully installed django-s3-file-field-client-1.1.0 girder-cli-oauth-client-0.4.0 isic-cli-12.4.0 isic-metadata-4.11.0 pyxdg-0.28 retryable-requests-0.1.2
# Requirement already satisfied: tensorflow==2.19.0 in /usr/local/lib/python3.12/dist-packages (2.19.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.0) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.0) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.0) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.0) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.0) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.0) (25.0)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 (from tensorflow==2.19.0)
#   Downloading protobuf-5.29.5-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.0) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.0) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.0) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.0) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.0) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.0) (1.17.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.0) (1.75.1)
# Requirement already satisfied: tensorboard~=2.19.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.0) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.0) (3.10.0)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.0) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.0) (3.14.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.19.0) (0.5.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow==2.19.0) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow==2.19.0) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow==2.19.0) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow==2.19.0) (0.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow==2.19.0) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow==2.19.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow==2.19.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow==2.19.0) (2025.10.5)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow==2.19.0) (3.9)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow==2.19.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow==2.19.0) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow==2.19.0) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow==2.19.0) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow==2.19.0) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow==2.19.0) (0.1.2)
# Downloading protobuf-5.29.5-cp38-abi3-manylinux2014_x86_64.whl (319 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.9/319.9 kB 7.8 MB/s eta 0:00:00
# Installing collected packages: protobuf
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 6.33.0
#     Uninstalling protobuf-6.33.0:
#       Successfully uninstalled protobuf-6.33.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colabsqlviz 0.2.5 requires protobuf<7.0.0,>=6.31.1, but you have protobuf 5.29.5 which is incompatible.
# grpcio-status 1.75.1 requires protobuf<7.0.0,>=6.31.1, but you have protobuf 5.29.5 which is incompatible.
# Successfully installed protobuf-5.29.5

# %%
#Descargar Imagenes + Metadatos
# !isic image download --search "" --collections "249" --limit 0 BCN20000/ # Imágenes y Metadatos de BCN20000
# Out:
# If you have been granted special permissions, logging in with `isic user login` might return more data.
#
# Downloading images + metadata (18,946 files, 1.2 GB) ━━━━━━━━━━━━━━ 100% 0:00:00
#
# Successfully downloaded 18,946 images to BCN20000/.
# Successfully wrote 18,946 metadata records to BCN20000/metadata.csv.
# Successfully wrote attributions to BCN20000/attribution.txt.
# Successfully wrote 1 license(s) to BCN20000/licenses.

# %%
#Visualización de Imagenes Descargadas
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

plt.figure(figsize=(15,15))
carpeta = '/content/BCN20000/' #Visualización de Imágenes para Entrenamiento
imagenes = os.listdir(carpeta)

for i , imagen in enumerate(imagenes[: 25]):
  plt.subplot(5, 5, i + 1)
  imagen = mpimg.imread(carpeta + '/' + imagen)
  plt.imshow(imagen)
  plt.axis("off")
plt.show()

# %%
import csv
def cargar_metadatos(archivo):
    datos = {
        'isic_id': [],
        'diagnosis_1': []  # Las etiquetas serán 0 o 1
    }
    etiquetas_validas = {'Benign': 0, 'Malignant': 1}  # Mapeamos las etiquetas a 0 y 1

    try:
        with open(archivo, 'r', encoding='utf-8') as f:
            reader = csv.reader(f)
            next(reader)  # Evita las columnas cabeceras.

            diagnosis_idx =7  # Cambiar al índice correspondiente si es necesario
            #7 para BCN20000
            for fila in reader:
                if len(fila) > diagnosis_idx:
                    diagnosis = fila[diagnosis_idx]
                    if diagnosis in etiquetas_validas:  # Solo almacenar Benign y Malignant
                        datos['isic_id'].append(fila[0])  # Almacena el ID de la imagen
                        datos['diagnosis_1'].append(etiquetas_validas[diagnosis])  # Asignamos la etiqueta 0 o 1
        print(f"Datos extraídos y filtrados correctamente. Se encontraron {len(datos['isic_id'])} registros válidos.")
        return datos

    except FileNotFoundError:
        print(f"Error: Archivo {archivo} no encontrado")
        return None

    except Exception as e:
        print(f"Error al procesar el archivo: {e}")
        return None

# %%
import os
import shutil
from sklearn.model_selection import train_test_split
from tqdm import tqdm

def organizar_imagenes_en_carpetas(carpeta_origen, metadatos, carpeta_destino_base):
    # Crea las carpetas de destino
    for split in ['train', 'test']:
        for class_name in ['benign', 'malignant']:
            os.makedirs(os.path.join(carpeta_destino_base, split, class_name), exist_ok=True)

    # Separa los IDs por clase
    ids_benignos = []
    ids_malignos = []
    for id_img, etiqueta in zip(metadatos['isic_id'], metadatos['diagnosis_1']):
        if etiqueta == 0:  # Benign
            ids_benignos.append(id_img)
        elif etiqueta == 1: # Malignant
            ids_malignos.append(id_img)

    # Divide los IDs en conjuntos de entrenamiento y prueba para cada clase
    ids_benignos_train, ids_benignos_test = train_test_split(ids_benignos, test_size=0.3, random_state=42)
    ids_malignos_train, ids_malignos_test = train_test_split(ids_malignos, test_size=0.3, random_state=42)

    # Función auxiliar para copiar archivos
    def copiar_archivos(ids, carpeta_destino):
        for id_img in tqdm(ids, desc=f'Copiando a {os.path.basename(carpeta_destino)}'):
            nombre_archivo = f"{id_img}.jpg"
            ruta_origen = os.path.join(carpeta_origen, nombre_archivo)
            ruta_destino = os.path.join(carpeta_destino, nombre_archivo)
            if os.path.exists(ruta_origen):
                shutil.copy(ruta_origen, ruta_destino)
            else:
                print(f"Advertencia: No se encontró el archivo {ruta_origen}")

    #  Copia los archivos a sus directorios finales
    print("Copiando imágenes de entrenamiento benignas...")
    copiar_archivos(ids_benignos_train, os.path.join(carpeta_destino_base, 'train', 'benign'))
    print("Copiando imágenes de entrenamiento malignas...")
    copiar_archivos(ids_malignos_train, os.path.join(carpeta_destino_base, 'train', 'malignant'))
    print("Copiando imágenes de prueba benignas...")
    copiar_archivos(ids_benignos_test, os.path.join(carpeta_destino_base, 'test', 'benign'))
    print("Copiando imágenes de prueba malignas...")
    copiar_archivos(ids_malignos_test, os.path.join(carpeta_destino_base, 'test', 'malignant'))
    print("\nImágenes organizadas correctamente en carpetas 'train' y 'test' sin fugas de datos.")

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, regularizers

# Lineamiento: L2 muy reducido
L2_REG = 1e-5

def Arq1_Refactorizada(input_shape=(224, 224, 3), num_classes=2):

    # Validar restricción SCCE
    if num_classes < 2:
        raise ValueError("num_classes debe ser 2 o más para sparse_categorical_crossentropy")

    model = models.Sequential([
        layers.Input(shape=input_shape),

        # Bloque 1
        layers.Conv2D(32, (3, 3), kernel_initializer='he_normal',
                      kernel_regularizer=regularizers.l2(L2_REG),
                      use_bias=False), # Bias innecesario antes de BN
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.Conv2D(32, (3, 3), kernel_initializer='he_normal',
                      kernel_regularizer=regularizers.l2(L2_REG),
                      use_bias=False),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.MaxPooling2D((2, 2)),

        # Bloque 2
        layers.Conv2D(64, (3, 3), kernel_initializer='he_normal',
                      kernel_regularizer=regularizers.l2(L2_REG),
                      use_bias=False),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.Conv2D(64, (3, 3), kernel_initializer='he_normal',
                      kernel_regularizer=regularizers.l2(L2_REG),
                      use_bias=False),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.MaxPooling2D((2, 2)),

        # Cabezal de Clasificación
        layers.GlobalAveragePooling2D(),
        layers.BatchNormalization(), # Estabilizar la salida de GAP
        layers.Dense(128, activation='relu',
                     kernel_regularizer=regularizers.l2(L2_REG)),
        layers.Dropout(0.5), # Mantener el Dropout fuerte

        # Capa de salida
        layers.Dense(num_classes, activation='softmax')
    ])

    return model

def Arq1_Optimizada_Refactorizada(input_shape=(224, 224, 3), num_classes=2):

    if num_classes < 2:
        raise ValueError("num_classes debe ser 2 o más para sparse_categorical_crossentropy")

    model = models.Sequential([
        layers.Input(shape=input_shape),

        # Bloque 1
        layers.Conv2D(32, (3, 3), padding='same', kernel_initializer='he_normal',
                      kernel_regularizer=regularizers.l2(L2_REG),
                      use_bias=False), # Bias innecesario antes de BN
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.Conv2D(32, (3, 3), padding='same', kernel_initializer='he_normal',
                      kernel_regularizer=regularizers.l2(L2_REG),
                      use_bias=False),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.MaxPooling2D((2, 2)),

        # Bloque 2
        layers.Conv2D(64, (3, 3), padding='same', kernel_initializer='he_normal',
                      kernel_regularizer=regularizers.l2(L2_REG),
                      use_bias=False),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.Conv2D(64, (3, 3), padding='same', kernel_initializer='he_normal',
                      kernel_regularizer=regularizers.l2(L2_REG),
                      use_bias=False),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.MaxPooling2D((2, 2)),

        # Cabezal de Clasificación
        layers.GlobalAveragePooling2D(),

        layers.Dense(num_classes, activation='softmax')
    ])

    return model

def Arq1_CapaPlana_Refactorizada(input_shape=(224, 224, 3), num_classes=2):

    if num_classes < 2:
        raise ValueError("num_classes debe ser 2 o más para sparse_categorical_crossentropy")

    model = models.Sequential([
        layers.Input(shape=input_shape),

        # Bloque 1
        layers.Conv2D(32, (3, 3), padding='same', kernel_initializer='he_normal',
                      kernel_regularizer=regularizers.l2(L2_REG),
                      use_bias=False), # Bias innecesario antes de BN
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.Conv2D(32, (3, 3), padding='same', kernel_initializer='he_normal',
                      kernel_regularizer=regularizers.l2(L2_REG),
                      use_bias=False),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.MaxPooling2D((2, 2)),

        # Bloque 2
        layers.Conv2D(64, (3, 3), padding='same', kernel_initializer='he_normal',
                      kernel_regularizer=regularizers.l2(L2_REG),
                      use_bias=False),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.Conv2D(64, (3, 3), padding='same', kernel_initializer='he_normal',
                      kernel_regularizer=regularizers.l2(L2_REG),
                      use_bias=False),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.MaxPooling2D((2, 2)),

        # Cabezal de Clasificación

        layers.GlobalAveragePooling2D(),
        layers.BatchNormalization(),
        layers.Dense(64, activation='relu',
                     kernel_regularizer=regularizers.l2(L2_REG)),
        layers.Dropout(0.5), # Se preserva el Dropout fuerte del cabezal
        layers.Dense(num_classes, activation='softmax')
    ])

    return model

def Arq2_Refactorizada(input_shape=(224, 224, 3), num_classes=2):
    if num_classes < 2:
        raise ValueError("num_classes debe ser 2 o más para sparse_categorical_crossentropy")

    model = models.Sequential([
        layers.Input(shape=input_shape),

        # Bloque 1
        layers.Conv2D(32, (3, 3), padding='same', kernel_initializer='he_normal',
                      kernel_regularizer=regularizers.l2(L2_REG),
                      use_bias=False), # Bias innecesario antes de BN
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.Conv2D(32, (3, 3), padding='same', kernel_initializer='he_normal',
                      kernel_regularizer=regularizers.l2(L2_REG),
                      use_bias=False),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.MaxPooling2D((2, 2)),

        # Bloque 2
        layers.Conv2D(64, (3, 3), padding='same', kernel_initializer='he_normal',
                      kernel_regularizer=regularizers.l2(L2_REG),
                      use_bias=False),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.Conv2D(64, (3, 3), padding='same', kernel_initializer='he_normal',
                      kernel_regularizer=regularizers.l2(L2_REG),
                      use_bias=False),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.MaxPooling2D((2, 2)),

        # Cabezal de Clasificación
        layers.Conv2D(128, (3, 3), padding='same', kernel_initializer='he_normal',
                      kernel_regularizer=regularizers.l2(L2_REG),
                      use_bias=False),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.Conv2D(128, (3, 3), padding='same', kernel_initializer='he_normal',
                      kernel_regularizer=regularizers.l2(L2_REG),
                      use_bias=False),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.MaxPooling2D((2, 2)),

        # Cabezal de Clasificación
        layers.GlobalAveragePooling2D(),
        layers.BatchNormalization(),
        layers.Dense(128, activation='relu',
                     kernel_regularizer=regularizers.l2(L2_REG)),
        layers.Dropout(0.5), # Se preserva el Dropout fuerte del cabezal

        # Capa de salida
        layers.Dense(num_classes, activation='softmax')
    ])

    return model

def Arq3_Refactorizada(input_shape=(224, 224, 3), num_classes=2):

    width_factor = 1.1

    if num_classes < 2:
        raise ValueError("num_classes debe ser 2 o más para sparse_categorical_crossentropy")

    model = models.Sequential([
        layers.Input(shape=input_shape),

        # Bloque 1
        layers.Conv2D(int(32 * width_factor), (3, 3), padding='same', kernel_initializer='he_normal',
                      kernel_regularizer=regularizers.l2(L2_REG), use_bias=False),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.MaxPooling2D((2, 2)),


        # Bloque 2
        layers.Conv2D(int(64 * width_factor), (3, 3), padding='same', kernel_initializer='he_normal',
                      kernel_regularizer=regularizers.l2(L2_REG), use_bias=False),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.Conv2D(int(64 * width_factor), (3, 3), padding='same', kernel_initializer='he_normal',
                      kernel_regularizer=regularizers.l2(L2_REG), use_bias=False),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.MaxPooling2D((2, 2)),

        # Bloque 3
        layers.Conv2D(int(128 * width_factor), (3, 3), padding='same', kernel_initializer='he_normal',
                      kernel_regularizer=regularizers.l2(L2_REG), use_bias=False),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.Conv2D(int(128 * width_factor), (3, 3), padding='same', kernel_initializer='he_normal',
                      kernel_regularizer=regularizers.l2(L2_REG), use_bias=False),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.Conv2D(int(128 * width_factor), (3, 3), padding='same', kernel_initializer='he_normal',
                      kernel_regularizer=regularizers.l2(L2_REG), use_bias=False),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.MaxPooling2D((2, 2)),

        # Cabezal de Clasificación
        layers.GlobalAveragePooling2D(),

        layers.BatchNormalization(),
        layers.Dense(int(512 * width_factor), activation='relu',
                     kernel_regularizer=regularizers.l2(L2_REG)),
        layers.Dropout(0.5),

        # Capa de salida
        layers.Dense(num_classes, activation='softmax')
    ])

    return model

L2_REG_SEP = 1e-5

def Arq4_Refactorizada(input_shape=(224, 224, 3), num_classes=2):
    if num_classes < 2:
        raise ValueError("num_classes debe ser 2 o más para sparse_categorical_crossentropy")

    model = models.Sequential([
        # Bloque de Entrada
        layers.Input(shape=input_shape),
        layers.Conv2D(32, (3, 3), padding='same', kernel_initializer='he_normal',
                      kernel_regularizer=regularizers.l2(L2_REG),
                      activation=None,
                      use_bias=False),
        layers.BatchNormalization(),
        layers.Activation('relu'),

        # Bloque Separable 1
        layers.SeparableConv2D(64, (3, 3), padding='same',
                               depthwise_initializer='he_normal',
                               pointwise_initializer='he_normal',
                               depthwise_regularizer=regularizers.l2(L2_REG_SEP),
                               pointwise_regularizer=regularizers.l2(L2_REG_SEP),
                               activation=None,
                               use_bias=False),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.MaxPooling2D((2, 2)),

        # Bloque Separable 2
        layers.SeparableConv2D(128, (3, 3), padding='same',
                               depthwise_initializer='he_normal',
                               pointwise_initializer='he_normal',
                               depthwise_regularizer=regularizers.l2(L2_REG_SEP),
                               pointwise_regularizer=regularizers.l2(L2_REG_SEP),
                               activation=None,
                               use_bias=False),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.MaxPooling2D((2, 2)),

        # Bloque Separable 3
        layers.SeparableConv2D(256, (3, 3), padding='same',
                               depthwise_initializer='he_normal',
                               pointwise_initializer='he_normal',
                               depthwise_regularizer=regularizers.l2(L2_REG_SEP),
                               pointwise_regularizer=regularizers.l2(L2_REG_SEP),
                               activation=None,
                               use_bias=False),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.MaxPooling2D((2, 2)),

        # Cabezal de Clasificación
        layers.GlobalAveragePooling2D(),
        layers.Dense(num_classes, activation='softmax')
    ])

    return model

# Creación de los modelos
Modelo_1_Normal_Refac = Arq1_Refactorizada()

Modelo_1_Optimizado_Refac = Arq1_Optimizada_Refactorizada()

Modelo_1_CapaPlana_Refac = Arq1_CapaPlana_Refactorizada()

Modelo_2_Refac = Arq2_Refactorizada()

Modelo_3_Refac = Arq3_Refactorizada()

Modelo_4_Refac = Arq4_Refactorizada()

# %% [markdown]
# ---
# APARTADO PARA GUARDAR Y DESCARGAR LOS MODELOS ENTRENADOS

# %% [markdown]
# ---
# APARTADO PARA CONVERTIR REGISTROS CSV A EXCEL

# %%
import os
import shutil

# Eliminar el directorio del dataset antiguo para evitar conflictos y asegurar una regeneración limpia
if os.path.exists('/content/dataset'):
    shutil.rmtree('/content/dataset')
    print("Directorio '/content/dataset' anterior eliminado.")
else:
    print("El directorio '/content/dataset' no existía, no fue necesaria ninguna limpieza.")
# Out:
# El directorio '/content/dataset' no existía, no fue necesaria ninguna limpieza.

# %%
# Asumiendo que los metadatos ya han sido cargados correctamente
metadatos = cargar_metadatos("/content/BCN20000/metadata.csv")
# Out:
# Datos extraídos y filtrados correctamente. Se encontraron 16702 registros válidos.

# %%
organizar_imagenes_en_carpetas('/content/BCN20000/', metadatos, '/content/dataset')
# Out:
# Copiando imágenes de entrenamiento benignas...
# Copiando a benign: 100%|██████████| 5481/5481 [00:00<00:00, 8896.28it/s]
# Copiando imágenes de entrenamiento malignas...
# Copiando a malignant: 100%|██████████| 6209/6209 [00:00<00:00, 8698.84it/s]
# Copiando imágenes de prueba benignas...
# Copiando a benign: 100%|██████████| 2350/2350 [00:00<00:00, 8560.61it/s]
# Copiando imágenes de prueba malignas...
# Copiando a malignant: 100%|██████████| 2662/2662 [00:00<00:00, 8772.39it/s]
# Imágenes organizadas correctamente en carpetas 'train' y 'test' sin fugas de datos.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os

def crear_generadores(carpeta_destino_base, batch_size=32):
  train_datagen = ImageDataGenerator(
      rescale=1./255,
      # Rangos Aumentados
      rotation_range=30, # Rotación.
      width_shift_range=0.2, # Traslación.
      height_shift_range=0.2,
      shear_range=20,
      zoom_range=[0.8, 1.2], # +-20% de zoom.
      vertical_flip=True, #Duplica la variabilidad.
      brightness_range=[0.8, 1.2], # Simula diferentes condiciones de iluminación.
      horizontal_flip=True,
      fill_mode='nearest',
      )
  # Generador de datos para validación
  test_datagen = ImageDataGenerator(rescale=1./255)

  # Crear generador para entrenamiento
  train_generator = train_datagen.flow_from_directory(
      os.path.join(carpeta_destino_base, 'train'),
      target_size=(224, 224),
      batch_size=batch_size, #32
      class_mode='sparse', # sparse_categorical_crossentropy
      shuffle=True
      )

  # Crear generador para validación
  validation_generator = test_datagen.flow_from_directory(
      os.path.join(carpeta_destino_base, 'test'),
      target_size=(224, 224),
      batch_size=batch_size,
      class_mode='sparse', # sparse_categorical_crossentropy
      shuffle=False # Correcto para validación
      )

  print("Generadores de datos (con aumentación agresiva) creados.")
  return train_generator, validation_generator

train_generator, validation_generator = crear_generadores('/content/dataset')
# Out:
# Found 11690 images belonging to 2 classes.
# Found 5012 images belonging to 2 classes.
# Generadores de datos (con aumentación agresiva) creados.

# %%
import tensorflow as tf

# Optimizador
rmsopti = tf.keras.optimizers.RMSprop(
    learning_rate = 0.0005,
    rho = 0.9,
    momentum = 0.0,
    epsilon = 1e-07,
)

METRICS = ['accuracy']

# Pérdida
loss_Focal = 'sparse_categorical_crossentropy'


Modelo_1_Normal_Refac.compile(optimizer=rmsopti,
                              loss=loss_Focal,
                              metrics=METRICS)

Modelo_1_Optimizado_Refac.compile(optimizer=rmsopti,
                                  loss=loss_Focal,
                                  metrics=METRICS)

Modelo_1_CapaPlana_Refac.compile(optimizer=rmsopti,
                                 loss=loss_Focal,
                                 metrics=METRICS)

Modelo_2_Refac.compile(optimizer=rmsopti,
                       loss=loss_Focal,
                       metrics=METRICS)

Modelo_3_Refac.compile(optimizer=rmsopti,
                       loss=loss_Focal,
                       metrics=METRICS)

Modelo_4_Refac.compile(optimizer=rmsopti,
                       loss=loss_Focal,
                       metrics=METRICS)

# %%
from tensorflow.keras.callbacks import TensorBoard, CSVLogger, ReduceLROnPlateau

# Create CSVLogger callbacks for each model to save epoch data to a CSV file
csv_logger_1_normal = CSVLogger('registro_entrenamiento_modelo_1_normal.csv', separator=',', append=False)
csv_logger_1_opt = CSVLogger('registro_entrenamiento_modelo_1_opt.csv', separator=',', append=False)
csv_logger_1_cplana = CSVLogger('registro_entrenamiento_modelo_1_cplana.csv', separator=',', append=False)
csv_logger_2 = CSVLogger('registro_entrenamiento_modelo_2.csv', separator=',', append=False)
csv_logger_3 = CSVLogger('registro_entrenamiento_modelo_3.csv', separator=',', append=False)
csv_logger_4 = CSVLogger('registro_entrenamiento_modelo_4.csv', separator=',', append=False)

# %%
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='accuracy', mode='max', factor=0.5, patience=5, verbose=1)

Model1 = TensorBoard(log_dir='logs/Model1')
history = Modelo_1_Normal_Refac.fit(
    train_generator,
    epochs=100,
    validation_data=validation_generator,
    callbacks=[csv_logger_1_normal, reduce_lr]
)
# Out:
# Epoch 1/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 0s 525ms/step - accuracy: 0.5933 - loss: 0.7380
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 233s 602ms/step - accuracy: 0.5934 - loss: 0.7379 - val_accuracy: 0.6508 - val_loss: 0.6437 - learning_rate: 5.0000e-04
# Epoch 2/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 208s 569ms/step - accuracy: 0.6378 - loss: 0.6537 - val_accuracy: 0.6365 - val_loss: 0.6409 - learning_rate: 5.0000e-04
# Epoch 3/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 210s 574ms/step - accuracy: 0.6576 - loss: 0.6361 - val_accuracy: 0.6828 - val_loss: 0.6069 - learning_rate: 5.0000e-04
# Epoch 4/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 205s 559ms/step - accuracy: 0.6615 - loss: 0.6332 - val_accuracy: 0.6854 - val_loss: 0.6083 - learning_rate: 5.0000e-04
# Epoch 5/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 205s 561ms/step - accuracy: 0.6607 - loss: 0.6289 - val_accuracy: 0.6901 - val_loss: 0.5996 - learning_rate: 5.0000e-04
# Epoch 6/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 206s 562ms/step - accuracy: 0.6782 - loss: 0.6175 - val_accuracy: 0.6838 - val_loss: 0.6026 - learning_rate: 5.0000e-04
# Epoch 7/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 207s 566ms/step - accuracy: 0.6718 - loss: 0.6154 - val_accuracy: 0.5996 - val_loss: 0.7194 - learning_rate: 5.0000e-04
# Epoch 8/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 211s 578ms/step - accuracy: 0.6684 - loss: 0.6204 - val_accuracy: 0.6899 - val_loss: 0.6028 - learning_rate: 5.0000e-04
# Epoch 9/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 210s 573ms/step - accuracy: 0.6757 - loss: 0.6096 - val_accuracy: 0.5341 - val_loss: 1.4297 - learning_rate: 5.0000e-04
# Epoch 10/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 207s 564ms/step - accuracy: 0.6776 - loss: 0.6122 - val_accuracy: 0.6939 - val_loss: 0.5939 - learning_rate: 5.0000e-04
# Epoch 11/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 211s 576ms/step - accuracy: 0.6869 - loss: 0.6077 - val_accuracy: 0.6913 - val_loss: 0.5906 - learning_rate: 5.0000e-04
# Epoch 12/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 210s 574ms/step - accuracy: 0.6706 - loss: 0.6143 - val_accuracy: 0.6937 - val_loss: 0.5877 - learning_rate: 5.0000e-04
# Epoch 13/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 209s 570ms/step - accuracy: 0.6753 - loss: 0.6028 - val_accuracy: 0.6562 - val_loss: 0.6368 - learning_rate: 5.0000e-04
# Epoch 14/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 208s 569ms/step - accuracy: 0.6883 - loss: 0.6033 - val_accuracy: 0.6690 - val_loss: 0.6125 - learning_rate: 5.0000e-04
# Epoch 15/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 211s 577ms/step - accuracy: 0.6734 - loss: 0.6100 - val_accuracy: 0.6692 - val_loss: 0.6141 - learning_rate: 5.0000e-04
# Epoch 16/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 207s 566ms/step - accuracy: 0.6791 - loss: 0.6082 - val_accuracy: 0.7061 - val_loss: 0.5819 - learning_rate: 5.0000e-04
# Epoch 17/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 207s 565ms/step - accuracy: 0.6839 - loss: 0.6061 - val_accuracy: 0.6939 - val_loss: 0.6022 - learning_rate: 5.0000e-04
# Epoch 18/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 204s 558ms/step - accuracy: 0.6943 - loss: 0.5957 - val_accuracy: 0.6808 - val_loss: 0.6195 - learning_rate: 5.0000e-04
# Epoch 19/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 213s 581ms/step - accuracy: 0.
# Epoch 94/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 205s 561ms/step - accuracy: 0.7267 - loss: 0.5565 - val_accuracy: 0.7354 - val_loss: 0.5425 - learning_rate: 1.5625e-05
# Epoch 95/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 0s 509ms/step - accuracy: 0.7235 - loss: 0.5536
# Epoch 95: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 210s 573ms/step - accuracy: 0.7235 - loss: 0.5535 - val_accuracy: 0.7342 - val_loss: 0.5434 - learning_rate: 1.5625e-05
# Epoch 96/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 204s 558ms/step - accuracy: 0.7288 - loss: 0.5485 - val_accuracy: 0.7378 - val_loss: 0.5424 - learning_rate: 7.8125e-06
# Epoch 97/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 205s 561ms/step - accuracy: 0.7285 - loss: 0.5478 - val_accuracy: 0.7388 - val_loss: 0.5430 - learning_rate: 7.8125e-06
# Epoch 98/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 216s 590ms/step - accuracy: 0.7266 - loss: 0.5489 - val_accuracy: 0.7376 - val_loss: 0.5431 - learning_rate: 7.8125e-06
# Epoch 99/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 205s 561ms/step - accuracy: 0.7246 - loss: 0.5550 - val_accuracy: 0.7372 - val_loss: 0.5445 - learning_rate: 7.8125e-06
# Epoch 100/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 0s 511ms/step - accuracy: 0.7289 - loss: 0.5480
# Epoch 100: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 210s 574ms/step - accuracy: 0.7289 - loss: 0.5480 - val_accuracy: 0.7366 - val_loss: 0.5436 - learning_rate: 7.8125e-06

# %%
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='accuracy', mode='max', factor=0.5, patience=5, verbose=1)

Modelo = TensorBoard(log_dir='logs/Model1o')
history = Modelo_1_Optimizado_Refac.fit(
    train_generator,
    epochs=100,
    validation_data=validation_generator,
    callbacks=[csv_logger_1_opt, reduce_lr]
)
# Out:
# Epoch 1/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 229s 595ms/step - accuracy: 0.6288 - loss: 0.6621 - val_accuracy: 0.6311 - val_loss: 0.6516 - learning_rate: 5.0000e-04
# Epoch 2/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 210s 575ms/step - accuracy: 0.6458 - loss: 0.6398 - val_accuracy: 0.6540 - val_loss: 0.6213 - learning_rate: 5.0000e-04
# Epoch 3/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 212s 580ms/step - accuracy: 0.6475 - loss: 0.6332 - val_accuracy: 0.6720 - val_loss: 0.6277 - learning_rate: 5.0000e-04
# Epoch 4/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 209s 572ms/step - accuracy: 0.6529 - loss: 0.6277 - val_accuracy: 0.6299 - val_loss: 0.6534 - learning_rate: 5.0000e-04
# Epoch 5/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 214s 583ms/step - accuracy: 0.6605 - loss: 0.6237 - val_accuracy: 0.6566 - val_loss: 0.6238 - learning_rate: 5.0000e-04
# Epoch 6/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 212s 580ms/step - accuracy: 0.6522 - loss: 0.6295 - val_accuracy: 0.6598 - val_loss: 0.6257 - learning_rate: 5.0000e-04
# Epoch 7/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 209s 570ms/step - accuracy: 0.6565 - loss: 0.6233 - val_accuracy: 0.6816 - val_loss: 0.6156 - learning_rate: 5.0000e-04
# Epoch 8/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 209s 570ms/step - accuracy: 0.6633 - loss: 0.6174 - val_accuracy: 0.6403 - val_loss: 0.6418 - learning_rate: 5.0000e-04
# Epoch 9/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 211s 576ms/step - accuracy: 0.6651 - loss: 0.6176 - val_accuracy: 0.6245 - val_loss: 0.6552 - learning_rate: 5.0000e-04
# Epoch 10/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 213s 582ms/step - accuracy: 0.6668 - loss: 0.6199 - val_accuracy: 0.6610 - val_loss: 0.6089 - learning_rate: 5.0000e-04
# Epoch 11/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 210s 574ms/step - accuracy: 0.6669 - loss: 0.6177 - val_accuracy: 0.6423 - val_loss: 0.6407 - learning_rate: 5.0000e-04
# Epoch 12/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 220s 602ms/step - accuracy: 0.6647 - loss: 0.6142 - val_accuracy: 0.6704 - val_loss: 0.6057 - learning_rate: 5.0000e-04
# Epoch 13/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 210s 574ms/step - accuracy: 0.6758 - loss: 0.6077 - val_accuracy: 0.6750 - val_loss: 0.6229 - learning_rate: 5.0000e-04
# Epoch 14/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 212s 579ms/step - accuracy: 0.6633 - loss: 0.6162 - val_accuracy: 0.6638 - val_loss: 0.6374 - learning_rate: 5.0000e-04
# Epoch 15/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 206s 562ms/step - accuracy: 0.6735 - loss: 0.6115 - val_accuracy: 0.6650 - val_loss: 0.6229 - learning_rate: 5.0000e-04
# Epoch 16/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 209s 571ms/step - accuracy: 0.6669 - loss: 0.6138 - val_accuracy: 0.5706 - val_loss: 0.9768 - learning_rate: 5.0000e-04
# Epoch 17/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 210s 575ms/step - accuracy: 0
# Epoch 93/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 208s 570ms/step - accuracy: 0.7217 - loss: 0.5586 - val_accuracy: 0.7113 - val_loss: 0.5630 - learning_rate: 7.8125e-06
# Epoch 94/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 207s 565ms/step - accuracy: 0.7275 - loss: 0.5557 - val_accuracy: 0.7163 - val_loss: 0.5613 - learning_rate: 7.8125e-06
# Epoch 95/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 209s 570ms/step - accuracy: 0.7194 - loss: 0.5607 - val_accuracy: 0.7129 - val_loss: 0.5629 - learning_rate: 7.8125e-06
# Epoch 96/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 206s 563ms/step - accuracy: 0.7204 - loss: 0.5679 - val_accuracy: 0.7149 - val_loss: 0.5608 - learning_rate: 7.8125e-06
# Epoch 97/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 210s 574ms/step - accuracy: 0.7129 - loss: 0.5656 - val_accuracy: 0.7117 - val_loss: 0.5629 - learning_rate: 7.8125e-06
# Epoch 98/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 213s 581ms/step - accuracy: 0.7184 - loss: 0.5654 - val_accuracy: 0.7159 - val_loss: 0.5620 - learning_rate: 7.8125e-06
# Epoch 99/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 210s 574ms/step - accuracy: 0.7276 - loss: 0.5569 - val_accuracy: 0.7143 - val_loss: 0.5615 - learning_rate: 7.8125e-06
# Epoch 100/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 207s 566ms/step - accuracy: 0.7117 - loss: 0.5675 - val_accuracy: 0.7155 - val_loss: 0.5617 - learning_rate: 7.8125e-06

# %%
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='accuracy', mode='max', factor=0.5, patience=5, verbose=1)

Model1cplana = TensorBoard(log_dir='logs/Model1cplana')
history = Modelo_1_CapaPlana_Refac.fit(
    train_generator,
    epochs=100,
    validation_data=validation_generator,
    callbacks=[csv_logger_1_cplana, reduce_lr]
)
# Out:
# Epoch 1/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 236s 611ms/step - accuracy: 0.5979 - loss: 0.7454 - val_accuracy: 0.6628 - val_loss: 0.6312 - learning_rate: 5.0000e-04
# Epoch 2/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 212s 578ms/step - accuracy: 0.6403 - loss: 0.6539 - val_accuracy: 0.6658 - val_loss: 0.6223 - learning_rate: 5.0000e-04
# Epoch 3/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 211s 577ms/step - accuracy: 0.6454 - loss: 0.6438 - val_accuracy: 0.6792 - val_loss: 0.6147 - learning_rate: 5.0000e-04
# Epoch 4/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 210s 575ms/step - accuracy: 0.6492 - loss: 0.6348 - val_accuracy: 0.6636 - val_loss: 0.6123 - learning_rate: 5.0000e-04
# Epoch 5/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 214s 586ms/step - accuracy: 0.6571 - loss: 0.6271 - val_accuracy: 0.5960 - val_loss: 0.6901 - learning_rate: 5.0000e-04
# Epoch 6/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 213s 582ms/step - accuracy: 0.6677 - loss: 0.6198 - val_accuracy: 0.6696 - val_loss: 0.6146 - learning_rate: 5.0000e-04
# Epoch 7/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 211s 576ms/step - accuracy: 0.6680 - loss: 0.6223 - val_accuracy: 0.6939 - val_loss: 0.5965 - learning_rate: 5.0000e-04
# Epoch 8/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 210s 574ms/step - accuracy: 0.6774 - loss: 0.6150 - val_accuracy: 0.5431 - val_loss: 0.9825 - learning_rate: 5.0000e-04
# Epoch 9/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 213s 581ms/step - accuracy: 0.6640 - loss: 0.6269 - val_accuracy: 0.6866 - val_loss: 0.5928 - learning_rate: 5.0000e-04
# Epoch 10/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 206s 564ms/step - accuracy: 0.6785 - loss: 0.6140 - val_accuracy: 0.6991 - val_loss: 0.5948 - learning_rate: 5.0000e-04
# Epoch 11/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 213s 582ms/step - accuracy: 0.6716 - loss: 0.6196 - val_accuracy: 0.6616 - val_loss: 0.6299 - learning_rate: 5.0000e-04
# Epoch 12/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 213s 583ms/step - accuracy: 0.6764 - loss: 0.6121 - val_accuracy: 0.6409 - val_loss: 0.6663 - learning_rate: 5.0000e-04
# Epoch 13/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 214s 584ms/step - accuracy: 0.6964 - loss: 0.6011 - val_accuracy: 0.6610 - val_loss: 0.6166 - learning_rate: 5.0000e-04
# Epoch 14/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 213s 583ms/step - accuracy: 0.6759 - loss: 0.6072 - val_accuracy: 0.6848 - val_loss: 0.6119 - learning_rate: 5.0000e-04
# Epoch 15/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 209s 572ms/step - accuracy: 0.6769 - loss: 0.6082 - val_accuracy: 0.6864 - val_loss: 0.6068 - learning_rate: 5.0000e-04
# Epoch 16/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 208s 568ms/step - accuracy: 0.6748 - loss: 0.6130 - val_accuracy: 0.6949 - val_loss: 0.5915 - learning_rate: 5.0000e-04
# Epoch 17/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 212s 579ms/step - accuracy: 0.
# Epoch 95/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 212s 579ms/step - accuracy: 0.7271 - loss: 0.5540 - val_accuracy: 0.7360 - val_loss: 0.5502 - learning_rate: 3.1250e-05
# Epoch 96/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 0s 515ms/step - accuracy: 0.7229 - loss: 0.5585
# Epoch 96: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 212s 580ms/step - accuracy: 0.7229 - loss: 0.5585 - val_accuracy: 0.7326 - val_loss: 0.5493 - learning_rate: 3.1250e-05
# Epoch 97/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 214s 585ms/step - accuracy: 0.7235 - loss: 0.5551 - val_accuracy: 0.7291 - val_loss: 0.5504 - learning_rate: 1.5625e-05
# Epoch 98/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 210s 574ms/step - accuracy: 0.7311 - loss: 0.5476 - val_accuracy: 0.7298 - val_loss: 0.5527 - learning_rate: 1.5625e-05
# Epoch 99/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 212s 579ms/step - accuracy: 0.7285 - loss: 0.5475 - val_accuracy: 0.7316 - val_loss: 0.5506 - learning_rate: 1.5625e-05
# Epoch 100/100
# 263/366 ━━━━━━━━━━━━━━━━━━━━ 52s 508ms/step - accuracy: 0.7253 - loss: 0.5473

# %%
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='accuracy', mode='max', factor=0.5, patience=5, verbose=1)

Model2 = TensorBoard(log_dir='logs/Model2')
history = Modelo_2_Refac.fit(
    train_generator,
    epochs=100,
    validation_data=validation_generator,
    callbacks=[csv_logger_2, reduce_lr]
    )
# Out:
# Epoch 1/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 230s 604ms/step - accuracy: 0.5870 - loss: 0.7862 - val_accuracy: 0.6397 - val_loss: 0.6405 - learning_rate: 5.0000e-04
# Epoch 2/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 213s 581ms/step - accuracy: 0.6380 - loss: 0.6596 - val_accuracy: 0.6576 - val_loss: 0.6573 - learning_rate: 5.0000e-04
# Epoch 3/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 217s 591ms/step - accuracy: 0.6534 - loss: 0.6424 - val_accuracy: 0.6770 - val_loss: 0.6155 - learning_rate: 5.0000e-04
# Epoch 4/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 211s 575ms/step - accuracy: 0.6631 - loss: 0.6381 - val_accuracy: 0.6596 - val_loss: 0.6222 - learning_rate: 5.0000e-04
# Epoch 5/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 213s 583ms/step - accuracy: 0.6681 - loss: 0.6292 - val_accuracy: 0.6931 - val_loss: 0.6131 - learning_rate: 5.0000e-04
# Epoch 6/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 212s 579ms/step - accuracy: 0.6712 - loss: 0.6214 - val_accuracy: 0.6614 - val_loss: 0.6164 - learning_rate: 5.0000e-04
# Epoch 7/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 214s 585ms/step - accuracy: 0.6877 - loss: 0.6095 - val_accuracy: 0.6706 - val_loss: 0.6208 - learning_rate: 5.0000e-04
# Epoch 8/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 214s 585ms/step - accuracy: 0.6829 - loss: 0.6081 - val_accuracy: 0.5315 - val_loss: 1.4648 - learning_rate: 5.0000e-04
# Epoch 9/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 217s 594ms/step - accuracy: 0.6902 - loss: 0.6054 - val_accuracy: 0.6899 - val_loss: 0.5952 - learning_rate: 5.0000e-04
# Epoch 10/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 216s 590ms/step - accuracy: 0.6922 - loss: 0.6055 - val_accuracy: 0.6606 - val_loss: 0.6211 - learning_rate: 5.0000e-04
# Epoch 11/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 211s 577ms/step - accuracy: 0.6906 - loss: 0.6079 - val_accuracy: 0.6887 - val_loss: 0.6008 - learning_rate: 5.0000e-04
# Epoch 12/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 210s 573ms/step - accuracy: 0.6983 - loss: 0.5988 - val_accuracy: 0.6808 - val_loss: 0.6034 - learning_rate: 5.0000e-04
# Epoch 13/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 213s 582ms/step - accuracy: 0.6924 - loss: 0.6023 - val_accuracy: 0.6997 - val_loss: 0.5945 - learning_rate: 5.0000e-04
# Epoch 14/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 213s 581ms/step - accuracy: 0.6998 - loss: 0.5971 - val_accuracy: 0.6935 - val_loss: 0.5957 - learning_rate: 5.0000e-04
# Epoch 15/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 214s 585ms/step - accuracy: 0.7086 - loss: 0.5922 - val_accuracy: 0.6792 - val_loss: 0.6164 - learning_rate: 5.0000e-04
# Epoch 16/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 212s 580ms/step - accuracy: 0.6977 - loss: 0.5940 - val_accuracy: 0.6997 - val_loss: 0.5852 - learning_rate: 5.0000e-04
# Epoch 17/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 211s 577ms/step - accuracy: 0.7042 - loss: 0.5880 - val_accuracy: 0.7151 - val_loss: 0.5757 - learning_rate: 5.0000e-04
# Epoch 18/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 215s 587ms/step - accuracy: 0.6935 - loss: 0.5978 - val_accuracy: 0.6630 - val_loss: 0.6265 - learning_rate: 5.0000e-04
# Epoch 19/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 213s 583ms/step - accuracy: 0.7011 - loss: 0.5941 - val_accuracy: 0.6830 - val_loss: 0.6004 - learning_rate: 5.0000e-04
# Epoch 20/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 210s 574ms/step - accuracy: 0.
# Epoch 94/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 215s 587ms/step - accuracy: 0.7714 - loss: 0.5000 - val_accuracy: 0.7612 - val_loss: 0.5186 - learning_rate: 1.5625e-05
# Epoch 95/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 213s 582ms/step - accuracy: 0.7621 - loss: 0.5064 - val_accuracy: 0.7628 - val_loss: 0.5200 - learning_rate: 1.5625e-05
# Epoch 96/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 216s 590ms/step - accuracy: 0.7624 - loss: 0.5022 - val_accuracy: 0.7572 - val_loss: 0.5252 - learning_rate: 1.5625e-05
# Epoch 97/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 0s 520ms/step - accuracy: 0.7625 - loss: 0.5117
# Epoch 97: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 213s 581ms/step - accuracy: 0.7625 - loss: 0.5117 - val_accuracy: 0.7602 - val_loss: 0.5189 - learning_rate: 1.5625e-05
# Epoch 98/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 211s 576ms/step - accuracy: 0.7660 - loss: 0.5015 - val_accuracy: 0.7624 - val_loss: 0.5173 - learning_rate: 7.8125e-06
# Epoch 99/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 213s 583ms/step - accuracy: 0.7674 - loss: 0.5049 - val_accuracy: 0.7594 - val_loss: 0.5195 - learning_rate: 7.8125e-06
# Epoch 100/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 212s 579ms/step - accuracy: 0.7691 - loss: 0.4982 - val_accuracy: 0.7602 - val_loss: 0.5202 - learning_rate: 7.8125e-06

# %%
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='accuracy', mode='max', factor=0.5, patience=5, verbose=1)

Model3 = TensorBoard(log_dir='logs/Model3')
history = Modelo_3_Refac.fit(
    train_generator,
    epochs=100,
    validation_data=validation_generator,
    callbacks=[csv_logger_3, reduce_lr]
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 254s 647ms/step - accuracy: 0.5992 - loss: 0.7696 - val_accuracy: 0.6844 - val_loss: 0.6287 - learning_rate: 5.0000e-04
# Epoch 2/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 213s 581ms/step - accuracy: 0.6433 - loss: 0.6759 - val_accuracy: 0.6472 - val_loss: 0.6956 - learning_rate: 5.0000e-04
# Epoch 3/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 212s 580ms/step - accuracy: 0.6470 - loss: 0.6539 - val_accuracy: 0.6580 - val_loss: 0.6351 - learning_rate: 5.0000e-04
# Epoch 4/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 213s 582ms/step - accuracy: 0.6517 - loss: 0.6438 - val_accuracy: 0.6870 - val_loss: 0.6232 - learning_rate: 5.0000e-04
# Epoch 5/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 213s 581ms/step - accuracy: 0.6726 - loss: 0.6327 - val_accuracy: 0.6792 - val_loss: 0.6256 - learning_rate: 5.0000e-04
# Epoch 6/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 211s 577ms/step - accuracy: 0.6735 - loss: 0.6301 - val_accuracy: 0.6977 - val_loss: 0.6135 - learning_rate: 5.0000e-04
# Epoch 7/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 215s 586ms/step - accuracy: 0.6718 - loss: 0.6294 - val_accuracy: 0.6961 - val_loss: 0.6433 - learning_rate: 5.0000e-04
# Epoch 8/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 214s 585ms/step - accuracy: 0.6727 - loss: 0.6279 - val_accuracy: 0.6901 - val_loss: 0.6047 - learning_rate: 5.0000e-04
# Epoch 9/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 215s 587ms/step - accuracy: 0.6829 - loss: 0.6154 - val_accuracy: 0.6864 - val_loss: 0.6229 - learning_rate: 5.0000e-04
# Epoch 10/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 214s 585ms/step - accuracy: 0.6740 - loss: 0.6232 - val_accuracy: 0.6965 - val_loss: 0.5995 - learning_rate: 5.0000e-04
# Epoch 11/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 214s 585ms/step - accuracy: 0.6818 - loss: 0.6117 - val_accuracy: 0.6987 - val_loss: 0.5979 - learning_rate: 5.0000e-04
# Epoch 12/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 213s 581ms/step - accuracy: 0.6774 - loss: 0.6230 - val_accuracy: 0.6832 - val_loss: 0.6086 - learning_rate: 5.0000e-04
# Epoch 13/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 210s 575ms/step - accuracy: 0.6929 - loss: 0.6044 - val_accuracy: 0.7157 - val_loss: 0.5968 - learning_rate: 5.0000e-04
# Epoch 14/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 214s 586ms/step - accuracy: 0.6944 - loss: 0.6006 - val_accuracy: 0.6999 - val_loss: 0.6005 - learning_rate: 5.0000e-04
# Epoch 15/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 212s 579ms/step - accuracy: 0.6935 - loss: 0.6002 - val_accuracy: 0.7137 - val_loss: 0.5815 - learning_rate: 5.0000e-04
# Epoch 16/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 213s 581ms/step - accuracy: 0.6906 - loss: 0.5993 - val_accuracy: 0.6923 - val_loss: 0.5953 - learning_rate: 5.0000e-04
# Epoch 17/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 215s 586ms/step - accuracy: 0.7012 - loss: 0.6010 - val_accuracy: 0.6975 - val_loss: 0.5924 - learning_rate: 5.0000e-04
# Epoch 18/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 221s 602ms/step - accuracy: 0.6966 - loss: 0.6015 - val_accuracy: 0.6973 - val_loss: 0.5926 - learning_rate: 5.0000e-04
# Epoch 19/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 213s
# Epoch 69/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 214s 584ms/step - accuracy: 0.7471 - loss: 0.5277 - val_accuracy: 0.7368 - val_loss: 0.6038 - learning_rate: 2.5000e-04
# Epoch 70/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 213s 581ms/step - accuracy: 0.7461 - loss: 0.5326 - val_accuracy: 0.7538 - val_loss: 0.5431 - learning_rate: 2.5000e-04
# Epoch 71/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 214s 584ms/step - accuracy: 0.7547 - loss: 0.5306 - val_accuracy: 0.6758 - val_loss: 0.6701 - learning_rate: 2.5000e-04
# Epoch 72/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 214s 584ms/step - accuracy: 0.7585 - loss: 0.5301 - val_accuracy: 0.7191 - val_loss: 0.6267 - learning_rate: 2.5000e-04
# Epoch 73/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 0s 520ms/step - accuracy: 0.7545 - loss: 0.5241
# Epoch 73: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 214s 584ms/step - accuracy: 0.7545 - loss: 0.5241 - val_accuracy: 0.7538 - val_loss: 0.5364 - learning_rate: 2.5000e-04
# Epoch 74/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 213s 582ms/step - accuracy: 0.7654 - loss: 0.5111 - val_accuracy: 0.7520 - val_loss: 0.5480 - learning_rate: 1.2500e-04
# Epoch 75/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 214s 584ms/step - accuracy: 0.7591 - loss: 0.5131 - val_accuracy: 0.7554 - val_loss: 0.5364 - learning_rate: 1.2500e-04
# Epoch 76/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 215s 586ms/step - accuracy: 0.7574 - loss: 0.5111 - val_accuracy: 0.7436 - val_loss: 0.5648 - learning_rate: 1.2500e-04
# Epoch 77/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 213s 581ms/step - accuracy: 0.7530 - loss: 0.5186 - val_accuracy: 0.7378 - val_loss: 0.5742 - learning_rate: 1.2500e-04
# Epoch 78/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 211s 577ms/step - accuracy: 0.7610 - loss: 0.5157 - val_accuracy: 0.7404 - val_loss: 0.5583 - learning_rate: 1.2500e-04
# Epoch 79/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 213s 581ms/step - accuracy: 0.7565 - loss: 0.5121 - val_accuracy: 0.7259 - val_loss: 0.6266 - learning_rate: 1.2500e-04
# Epoch 80/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 212s 580ms/step - accuracy: 0.7589 - loss: 0.5207 - val_accuracy: 0.7572 - val_loss: 0.5375 - learning_rate: 1.2500e-04
# Epoch 81/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 211s 577ms/step - accuracy: 0.7538 - loss: 0.5166 - val_accuracy: 0.7500 - val_loss: 0.5508 - learning_rate: 1.2500e-04
# Epoch 82/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 216s 589ms/step - accuracy: 0.7572 - loss: 0.5104 - val_accuracy: 0.7472 - val_loss: 0.5416 - learning_rate: 1.2500e-04
# Epoch 83/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 212s 580ms/step - accuracy: 0.7695 - loss: 0.4986 - val_accuracy: 0.7598 - val_loss: 0.5301 - learning_rate: 1.2500e-04
# Epoch 84/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 213s 583ms/step - accuracy: 0.7639 - loss: 0.5036 - val_accuracy: 0.7490 - val_loss: 0.5353 - learning_rate: 1.2500e-04
# Epoch 85/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 213s 582ms/step - accuracy: 0.7704 - loss: 0.5095 - val_accuracy: 0.7189 - val_loss: 0.6212 - learning_rate: 1.2500e-04
# Epoch 86/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 213s 582ms/step - accuracy: 0.7629 - loss: 0.5120 - val_accuracy: 0.7562 - val_loss: 0.5489 - learning_rate: 1.2500e-04
# Epoch 87/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 212s 578ms/step - accuracy: 0.7691 - loss: 0.4967 - val_accuracy: 0.7556 - val_loss: 0.5385 - learning_rate: 1.2500e-04
# Epoch 88/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 211s 577ms/step - accuracy: 0.7599 - loss: 0.5163 - val_accuracy: 0.7506 - val_loss: 0.5617 - learning_rate: 1.2500e-04
# Epoch 89/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 214s 583ms/step - accuracy: 0.7672 - loss: 0.5019 - val_accuracy: 0.7251 - val_loss: 0.5818 - learning_rate: 1.2500e-04
# Epoch 90/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 0s 514ms/step - accuracy: 0.7733 - loss: 0.4972
# Epoch 90: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 212s 580ms/step - accuracy: 0.7733 - loss: 0.4972 - val_accuracy: 0.7067 - val_loss: 0.6608 - learning_rate: 1.2500e-04
# Epoch 91/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 210s 575ms/step - accuracy: 0.7657 - loss: 0.5098 - val_accuracy: 0.7548 - val_loss: 0.5462 - learning_rate: 6.2500e-05
# Epoch 92/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 212s 580ms/step - accuracy: 0.7667 - loss: 0.4982 - val_accuracy: 0.7524 - val_loss: 0.5560 - learning_rate: 6.2500e-05
# Epoch 93/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 211s 577ms/step - accuracy: 0.7687 - loss: 0.4946 - val_accuracy: 0.7620 - val_loss: 0.5262 - learning_rate: 6.2500e-05
# Epoch 94/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 210s 573ms/step - accuracy: 0.7678 - loss: 0.4931 - val_accuracy: 0.7588 - val_loss: 0.5458 - learning_rate: 6.2500e-05
# Epoch 95/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 211s 577ms/step - accuracy: 0.7681 - loss: 0.4945 - val_accuracy: 0.7540 - val_loss: 0.5479 - learning_rate: 6.2500e-05
# Epoch 96/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 212s 578ms/step - accuracy: 0.7725 - loss: 0.4882 - val_accuracy: 0.7628 - val_loss: 0.5261 - learning_rate: 6.2500e-05
# Epoch 97/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 212s 579ms/step - accuracy: 0.7775 - loss: 0.4883 - val_accuracy: 0.7566 - val_loss: 0.5373 - learning_rate: 6.2500e-05
# Epoch 98/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 212s 580ms/step - accuracy: 0.7750 - loss: 0.4918 - val_accuracy: 0.7544 - val_loss: 0.5447 - learning_rate: 6.2500e-05
# Epoch 99/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 212s 578ms/step - accuracy: 0.7679 - loss: 0.5009 - val_accuracy: 0.7640 - val_loss: 0.5298 - learning_rate: 6.2500e-05
# Epoch 100/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 212s 579ms/step - accuracy: 0.7684 - loss: 0.4945 - val_accuracy: 0.7572 - val_loss: 0.5561 - learning_rate: 6.2500e-05

# %%
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='accuracy', mode='max', factor=0.5, patience=5, verbose=1)

Model4 = TensorBoard(log_dir='logs/Model4')
history = Modelo_4_Refac.fit(
    train_generator,
    epochs=100,
    validation_data=validation_generator,
    callbacks=[csv_logger_4, reduce_lr]
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 248s 630ms/step - accuracy: 0.6358 - loss: 0.6562 - val_accuracy: 0.5950 - val_loss: 0.6865 - learning_rate: 5.0000e-04
# Epoch 2/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 209s 571ms/step - accuracy: 0.6513 - loss: 0.6339 - val_accuracy: 0.6662 - val_loss: 0.6283 - learning_rate: 5.0000e-04
# Epoch 3/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 211s 576ms/step - accuracy: 0.6522 - loss: 0.6354 - val_accuracy: 0.6842 - val_loss: 0.6263 - learning_rate: 5.0000e-04
# Epoch 4/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 209s 572ms/step - accuracy: 0.6686 - loss: 0.6216 - val_accuracy: 0.6664 - val_loss: 0.6189 - learning_rate: 5.0000e-04
# Epoch 5/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 215s 587ms/step - accuracy: 0.6569 - loss: 0.6278 - val_accuracy: 0.6911 - val_loss: 0.5994 - learning_rate: 5.0000e-04
# Epoch 6/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 212s 578ms/step - accuracy: 0.6739 - loss: 0.6167 - val_accuracy: 0.6728 - val_loss: 0.6263 - learning_rate: 5.0000e-04
# Epoch 7/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 215s 586ms/step - accuracy: 0.6763 - loss: 0.6084 - val_accuracy: 0.6516 - val_loss: 0.6217 - learning_rate: 5.0000e-04
# Epoch 8/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 212s 578ms/step - accuracy: 0.6786 - loss: 0.6105 - val_accuracy: 0.6716 - val_loss: 0.6114 - learning_rate: 5.0000e-04
# Epoch 9/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 212s 578ms/step - accuracy: 0.6760 - loss: 0.6097 - val_accuracy: 0.7009 - val_loss: 0.5934 - learning_rate: 5.0000e-04
# Epoch 10/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 212s 580ms/step - accuracy: 0.6750 - loss: 0.6103 - val_accuracy: 0.6802 - val_loss: 0.6309 - learning_rate: 5.0000e-04
# Epoch 11/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 213s 583ms/step - accuracy: 0.6840 - loss: 0.6070 - val_accuracy: 0.6995 - val_loss: 0.5937 - learning_rate: 5.0000e-04
# Epoch 12/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 210s 574ms/step - accuracy: 0.6927 - loss: 0.5941 - val_accuracy: 0.6989 - val_loss: 0.5878 - learning_rate: 5.0000e-04
# Epoch 13/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 210s 572ms/step - accuracy: 0.6916 - loss: 0.5993 - val_accuracy: 0.6887 - val_loss: 0.5925 - learning_rate: 5.0000e-04
# Epoch 14/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 210s 572ms/step - accuracy: 0.6833 - loss: 0.5984 - val_accuracy: 0.6506 - val_loss: 0.6634 - learning_rate: 5.0000e-04
# Epoch 15/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 212s 579ms/step - accuracy: 0.6904 - loss: 0.5979 - val_accuracy: 0.6449 - val_loss: 0.6358 - learning_rate: 5.0000e-04
# Epoch 16/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 211s 576ms/step - accuracy: 0.6915 - loss: 0.5989 - val_accuracy: 0.7013 - val_loss: 0.6087 - learning_rate: 5.0000e-04
# Epoch 17/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 209s 571ms/step - accuracy: 0.6993 - loss: 0.5895 - val_accuracy: 0.7075 - val_loss: 0.5802 - learning_rate: 5.0000e-04
# Epoch 18/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 214s 583ms/step - accuracy: 0.6959 - loss: 0.5949 - val_accuracy: 0.7035 - val_loss: 0.5840 - learning_rate: 5.0000e-04
# Epoch 19/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 207s 565ms/step - accuracy: 0.6908 - loss: 0.5908 - val_accuracy: 0.6997 - val_loss: 0.5935 - learning_rate: 5.0000e-04
# Epoch 20/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 219s 597ms/step - accuracy: 0.6961 - loss: 0.5908 - val_accuracy: 0.7039 - val_loss: 0.5790 - learning_rate: 5.0000e-04
# Epoch 21/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 208s 569ms/step - accuracy: 0.6943 - loss: 0.5924 - val_accuracy: 0.7069 - val_loss: 0.5913 - learning_rate: 5.0000e-04
# Epoch 22/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 209s 572ms/step - accuracy: 0.6962 - loss: 0.5883 - val_accuracy: 0.7107 - val_loss: 0.5760 - learning_rate: 5.0000e-04
# Epoch 23/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 211s 577ms/step - accuracy: 0.7055 - loss: 0.5826 - val_accuracy: 0.6756 - val_loss: 0.6259 - learning_rate: 5.0000e-04
# Epoch 24/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 212s 578ms/step - accuracy: 0.6966 - loss: 0.5889 - val_accuracy: 0.6957 - val_loss: 0.5874 - learning_rate: 5.0000e-04
# Epoch 25/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 207s 566ms/step - accuracy: 0.7054 - loss: 0.5882 - val_accuracy: 0.6866 - val_loss: 0.6130 - learning_rate: 5.0000e-04
# Epoch 26/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 210s 575ms/step - accuracy: 0.6987 - loss: 0.5873 - val_accuracy: 0.6999 - val_loss: 0.5832 - learning_rate: 5.0000e-04
# Epoch 27/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 212s 579ms/step - accuracy: 0.7009 - loss: 0.5887 - val_accuracy: 0.7081 - val_loss: 0.5851 - learning_rate: 5.0000e-04
# Epoch 28/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 210s 574ms/step - accuracy: 0.7067 - loss: 0.5772 - val_accuracy: 0.7195 - val_loss: 0.5731 - learning_rate: 5.0000e-04
# Epoch 29/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 214s 584ms/step - accuracy: 0.6992 - loss: 0.5915 - val_accuracy: 0.7049 - val_loss: 0.5829 - learning_rate: 5.0000e-04
# Epoch 30/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 210s 573ms/step - accuracy: 0.7007 - loss: 0.5877 - val_accuracy: 0.7037 - val_loss: 0.5816 - learning_rate: 5.0000e-04
# Epoch 31/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 211s 576ms/step - accuracy: 0.6988 - loss: 0.5857 - val_accuracy: 0.6957 - val_loss: 0.5781 - learning_rate: 5.0000e-04
# Epoch 32/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 209s 572ms/step - accuracy: 0.7056 - loss: 0.5800 - val_accuracy: 0.7029 - val_loss: 0.5757 - learning_rate: 5.0000e-04
# Epoch 33/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 210s 574ms/step - accuracy: 0.7053 - loss: 0.5789 - val_accuracy: 0.7059 - val_loss: 0.5769 - learning_rate: 5.0000e-04
# Epoch 34/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 208s 567ms/step - accuracy: 0.7000 - loss: 0.5834 - val_accuracy: 0.6866 - val_loss: 0.5941 - learning_rate: 5.0000e-04
# Epoch 35/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 212s 579ms/step - accuracy: 0.7095 - loss: 0.5737 - val_accuracy: 0.7059 - val_loss: 0.5734 - learning_rate: 5.0000e-04
# Epoch 36/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 206s 564ms/step - accuracy: 0.7055 - loss: 0.5792 - val_accuracy: 0.7107 - val_loss: 0.5659 - learning_rate: 5.0000e-04
# Epoch 37/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 213s 582ms/step - accuracy: 0.6960 - loss: 0.5769 - val_accuracy: 0.7105 - val_loss: 0.5792 - learning_rate: 5.0000e-04
# Epoch 38/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 211s 577ms/step - accuracy: 0.7161 - loss: 0.5715 - val_accuracy: 0.6891 - val_loss: 0.5995 - learning_rate: 5.0000e-04
# Epoch 39/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 209s 570ms/step - accuracy: 0.7014 - loss: 0.5799 - val_accuracy: 0.7077 - val_loss: 0.5709 - learning_rate: 5.0000e-04
# Epoch 40/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 217s 593ms/step - accuracy: 0.7050 - loss: 0.5784 - val_accuracy: 0.6901 - val_loss: 0.5770 - learning_rate: 5.0000e-04
# Epoch 41/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 211s 577ms/step - accuracy: 0.7070 - loss: 0.5784 - val_accuracy: 0.6917 - val_loss: 0.5906 - learning_rate: 5.0000e-04
# Epoch 42/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 211s 577ms/step - accuracy: 0.7088 - loss: 0.5694 - val_accuracy: 0.6881 - val_loss: 0.5849 - learning_rate: 5.0000e-04
# Epoch 43/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 209s 572ms/step - accuracy: 0.7093 - loss: 0.5767 - val_accuracy: 0.6528 - val_loss: 0.6492 - learning_rate: 5.0000e-04
# Epoch 44/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 211s 576ms/step - accuracy: 0.7123 - loss: 0.5682 - val_accuracy: 0.6969 - val_loss: 0.5851 - learning_rate: 5.0000e-04
# Epoch 45/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 208s 569ms/step - accuracy: 0.7075 - loss: 0.5757 - val_accuracy: 0.6977 - val_loss: 0.6038 - learning_rate: 5.0000e-04
# Epoch 46/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 209s 571ms/step - accuracy: 0.7150 - loss: 0.5597 - val_accuracy: 0.7105 - val_loss: 0.5731 - learning_rate: 5.0000e-04
# Epoch 47/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 210s 573ms/step - accuracy: 0.7068 - loss: 0.5799 - val_accuracy: 0.7063 - val_loss: 0.5744 - learning_rate: 5.0000e-04
# Epoch 48/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 211s 575ms/step - accuracy: 0.6980 - loss: 0.5752 - val_accuracy: 0.7105 - val_loss: 0.5684 - learning_rate: 5.0000e-04
# Epoch 49/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 209s 572ms/step - accuracy: 0.7174 - loss: 0.5660 - val_accuracy: 0.7117 - val_loss: 0.5612 - learning_rate: 5.0000e-04
# Epoch 50/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 211s 577ms/step - accuracy: 0.7101 - loss: 0.5769 - val_accuracy: 0.6696 - val_loss: 0.6187 - learning_rate: 5.0000e-04
# Epoch 51/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 0s 505ms/step - accuracy: 0.7238 - loss: 0.5625
# Epoch 51: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 212s 578ms/step - accuracy: 0.7238 - loss: 0.5625 - val_accuracy: 0.7047 - val_loss: 0.5862 - learning_rate: 5.0000e-04
# Epoch 52/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 210s 574ms/step - accuracy: 0.7201 - loss: 0.5576 - val_accuracy: 0.7179 - val_loss: 0.5625 - learning_rate: 2.5000e-04
# Epoch 53/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 213s 582ms/step - accuracy: 0.7172 - loss: 0.5608 - val_accuracy: 0.7227 - val_loss: 0.5576 - learning_rate: 2.5000e-04
# Epoch 54/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 208s 569ms/step - accuracy: 0.7222 - loss: 0.5622 - val_accuracy: 0.7055 - val_loss: 0.5902 - learning_rate: 2.5000e-04
# Epoch 55/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 208s 568ms/step - accuracy: 0.7216 - loss: 0.5571 - val_accuracy: 0.7107 - val_loss: 0.5732 - learning_rate: 2.5000e-04
# Epoch 56/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 209s 570ms/step - accuracy: 0.7193 - loss: 0.5623 - val_accuracy: 0.7131 - val_loss: 0.5593 - learning_rate: 2.5000e-04
# Epoch 57/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 218s 596ms/step - accuracy: 0.7299 - loss: 0.5563 - val_accuracy: 0.7167 - val_loss: 0.5652 - learning_rate: 2.5000e-04
# Epoch 58/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 207s 567ms/step - accuracy: 0.7183 - loss: 0.5623 - val_accuracy: 0.7159 - val_loss: 0.5636 - learning_rate: 2.5000e-04
# Epoch 59/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 209s 572ms/step - accuracy: 0.7132 - loss: 0.5627 - val_accuracy: 0.6750 - val_loss: 0.6389 - learning_rate: 2.5000e-04
# Epoch 60/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 212s 578ms/step - accuracy: 0.7247 - loss: 0.5538 - val_accuracy: 0.7149 - val_loss: 0.5655 - learning_rate: 2.5000e-04
# Epoch 61/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 214s 584ms/step - accuracy: 0.7123 - loss: 0.5613 - val_accuracy: 0.6933 - val_loss: 0.6006 - learning_rate: 2.5000e-04
# Epoch 62/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 0s 508ms/step - accuracy: 0.7231 - loss: 0.5599
# Epoch 62: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 209s 571ms/step - accuracy: 0.7231 - loss: 0.5599 - val_accuracy: 0.7147 - val_loss: 0.5715 - learning_rate: 2.5000e-04
# Epoch 63/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 209s 571ms/step - accuracy: 0.7178 - loss: 0.5580 - val_accuracy: 0.7215 - val_loss: 0.5504 - learning_rate: 1.2500e-04
# Epoch 64/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 214s 585ms/step - accuracy: 0.7227 - loss: 0.5556 - val_accuracy: 0.7177 - val_loss: 0.5632 - learning_rate: 1.2500e-04
# Epoch 65/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 210s 575ms/step - accuracy: 0.7256 - loss: 0.5486 - val_accuracy: 0.7233 - val_loss: 0.5530 - learning_rate: 1.2500e-04
# Epoch 66/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 214s 586ms/step - accuracy: 0.7228 - loss: 0.5553 - val_accuracy: 0.7207 - val_loss: 0.5569 - learning_rate: 1.2500e-04
# Epoch 67/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 212s 579ms/step - accuracy: 0.7262 - loss: 0.5521 - val_accuracy: 0.7143 - val_loss: 0.5675 - learning_rate: 1.2500e-04
# Epoch 68/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 215s 587ms/step - accuracy: 0.7276 - loss: 0.5463 - val_accuracy: 0.7255 - val_loss: 0.5492 - learning_rate: 1.2500e-04
# Epoch 69/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 211s 577ms/step - accuracy: 0.7266 - loss: 0.5527 - val_accuracy: 0.7213 - val_loss: 0.5581 - learning_rate: 1.2500e-04
# Epoch 70/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 214s 583ms/step - accuracy: 0.7339 - loss: 0.5469 - val_accuracy: 0.7239 - val_loss: 0.5519 - learning_rate: 1.2500e-04
# Epoch 71/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 214s 585ms/step - accuracy: 0.7317 - loss: 0.5439 - val_accuracy: 0.7219 - val_loss: 0.5507 - learning_rate: 1.2500e-04
# Epoch 72/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 0s 509ms/step - accuracy: 0.7252 - loss: 0.5531
# Epoch 72: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 209s 571ms/step - accuracy: 0.7252 - loss: 0.5531 - val_accuracy: 0.7271 - val_loss: 0.5494 - learning_rate: 1.2500e-04
# Epoch 73/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 211s 577ms/step - accuracy: 0.7340 - loss: 0.5465 - val_accuracy: 0.7241 - val_loss: 0.5494 - learning_rate: 6.2500e-05
# Epoch 74/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 215s 586ms/step - accuracy: 0.7357 - loss: 0.5440 - val_accuracy: 0.7221 - val_loss: 0.5520 - learning_rate: 6.2500e-05
# Epoch 75/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 213s 582ms/step - accuracy: 0.7310 - loss: 0.5431 - val_accuracy: 0.7197 - val_loss: 0.5581 - learning_rate: 6.2500e-05
# Epoch 76/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 213s 582ms/step - accuracy: 0.7251 - loss: 0.5513 - val_accuracy: 0.7209 - val_loss: 0.5531 - learning_rate: 6.2500e-05
# Epoch 77/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 213s 581ms/step - accuracy: 0.7312 - loss: 0.5440 - val_accuracy: 0.7185 - val_loss: 0.5532 - learning_rate: 6.2500e-05
# Epoch 78/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 210s 574ms/step - accuracy: 0.7340 - loss: 0.5432 - val_accuracy: 0.7239 - val_loss: 0.5482 - learning_rate: 6.2500e-05
# Epoch 79/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 208s 569ms/step - accuracy: 0.7324 - loss: 0.5472 - val_accuracy: 0.7241 - val_loss: 0.5474 - learning_rate: 6.2500e-05
# Epoch 80/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 209s 572ms/step - accuracy: 0.7349 - loss: 0.5453 - val_accuracy: 0.7193 - val_loss: 0.5555 - learning_rate: 6.2500e-05
# Epoch 81/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 211s 575ms/step - accuracy: 0.7270 - loss: 0.5512 - val_accuracy: 0.7237 - val_loss: 0.5510 - learning_rate: 6.2500e-05
# Epoch 82/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 212s 578ms/step - accuracy: 0.7297 - loss: 0.5498 - val_accuracy: 0.7191 - val_loss: 0.5529 - learning_rate: 6.2500e-05
# Epoch 83/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 211s 578ms/step - accuracy: 0.7285 - loss: 0.5494 - val_accuracy: 0.7179 - val_loss: 0.5609 - learning_rate: 6.2500e-05
# Epoch 84/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 207s 566ms/step - accuracy: 0.7446 - loss: 0.5371 - val_accuracy: 0.7217 - val_loss: 0.5495 - learning_rate: 6.2500e-05
# Epoch 85/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 208s 569ms/step - accuracy: 0.7271 - loss: 0.5528 - val_accuracy: 0.7211 - val_loss: 0.5569 - learning_rate: 6.2500e-05
# Epoch 86/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 209s 570ms/step - accuracy: 0.7246 - loss: 0.5495 - val_accuracy: 0.7201 - val_loss: 0.5518 - learning_rate: 6.2500e-05
# Epoch 87/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 214s 585ms/step - accuracy: 0.7310 - loss: 0.5425 - val_accuracy: 0.7181 - val_loss: 0.5628 - learning_rate: 6.2500e-05
# Epoch 88/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 208s 567ms/step - accuracy: 0.7299 - loss: 0.5476 - val_accuracy: 0.7191 - val_loss: 0.5522 - learning_rate: 6.2500e-05
# Epoch 89/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 0s 514ms/step - accuracy: 0.7271 - loss: 0.5463
# Epoch 89: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 211s 575ms/step - accuracy: 0.7271 - loss: 0.5463 - val_accuracy: 0.7235 - val_loss: 0.5558 - learning_rate: 6.2500e-05
# Epoch 90/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 210s 575ms/step - accuracy: 0.7425 - loss: 0.5365 - val_accuracy: 0.7217 - val_loss: 0.5522 - learning_rate: 3.1250e-05
# Epoch 91/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 207s 566ms/step - accuracy: 0.7403 - loss: 0.5449 - val_accuracy: 0.7233 - val_loss: 0.5499 - learning_rate: 3.1250e-05
# Epoch 92/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 210s 573ms/step - accuracy: 0.7278 - loss: 0.5479 - val_accuracy: 0.7201 - val_loss: 0.5492 - learning_rate: 3.1250e-05
# Epoch 93/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 210s 573ms/step - accuracy: 0.7365 - loss: 0.5395 - val_accuracy: 0.7219 - val_loss: 0.5507 - learning_rate: 3.1250e-05
# Epoch 94/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 0s 516ms/step - accuracy: 0.7281 - loss: 0.5487
# Epoch 94: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 213s 581ms/step - accuracy: 0.7281 - loss: 0.5487 - val_accuracy: 0.7199 - val_loss: 0.5517 - learning_rate: 3.1250e-05
# Epoch 95/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 209s 570ms/step - accuracy: 0.7351 - loss: 0.5387 - val_accuracy: 0.7211 - val_loss: 0.5502 - learning_rate: 1.5625e-05
# Epoch 96/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 211s 575ms/step - accuracy: 0.7364 - loss: 0.5365 - val_accuracy: 0.7201 - val_loss: 0.5516 - learning_rate: 1.5625e-05
# Epoch 97/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 211s 576ms/step - accuracy: 0.7392 - loss: 0.5392 - val_accuracy: 0.7213 - val_loss: 0.5544 - learning_rate: 1.5625e-05
# Epoch 98/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 211s 577ms/step - accuracy: 0.7371 - loss: 0.5427 - val_accuracy: 0.7213 - val_loss: 0.5511 - learning_rate: 1.5625e-05
# Epoch 99/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 0s 505ms/step - accuracy: 0.7291 - loss: 0.5469
# Epoch 99: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 210s 572ms/step - accuracy: 0.7291 - loss: 0.5469 - val_accuracy: 0.7215 - val_loss: 0.5514 - learning_rate: 1.5625e-05
# Epoch 100/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 213s 582ms/step - accuracy: 0.7315 - loss: 0.5473 - val_accuracy: 0.7199 - val_loss: 0.5520 - learning_rate: 7.8125e-06

# %%
import os

# Crear la carpeta para guardar los modelos si no existe
os.makedirs('/content/MisModelos', exist_ok=True)

# Guardar los modelos entrenados
print("Guardando modelos...")
Modelo_1_Normal_Refac.save('/content/MisModelos/Modelo_1_Normal.h5')
Modelo_1_Optimizado_Refac.save('/content/MisModelos/Modelo_1_Optimizado.h5')
Modelo_1_CapaPlana_Refac.save('/content/MisModelos/Modelo_1_CapaPlana.h5')
Modelo_2_Refac.save('/content/MisModelos/Modelo_2.h5')
Modelo_3_Refac.save('/content/MisModelos/Modelo_3.h5')
Modelo_4_Refac.save('/content/MisModelos/Modelo_4.h5')

print("Modelos guardados exitosamente en /content/MisModelos/")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Guardando modelos...
# Modelos guardados exitosamente en /content/MisModelos/

# %%
from google.colab import files
import os

# Ruta del modelo específico que se guardó en la celda anterior
modelo_path = '/content/MisModelos/Modelo_1_Normal.h5'

print(f"Intentando descargar el modelo: {os.path.basename(modelo_path)}")

# Verificar si el archivo del modelo existe antes de iniciar la descarga
if os.path.exists(modelo_path):
    files.download(modelo_path)
    print("\nDescarga completada exitosamente.")
else:
    print(f"\nError: No se encontró el archivo del modelo en la ruta especificada: {modelo_path}")
    print("Por favor, asegúrate de que la celda anterior para guardar el modelo se haya ejecutado sin errores.")
# Out:
# Intentando descargar el modelo: Modelo_4.h5
# Descarga completada exitosamente.

# %%
import pandas as pd
import os

def convertir_csv_a_excel(ruta_csv, ruta_excel):
    """
    Lee un archivo CSV de métricas y lo convierte a un archivo XLSX.
    """
    if not os.path.exists(ruta_csv):
        print(f"Advertencia: El archivo CSV no fue encontrado en la ruta: {ruta_csv}")
        return False

    try:
        # 1. Leer el archivo CSV con pandas
        df = pd.read_csv(ruta_csv)

        # 2. Guardar el DataFrame como archivo Excel
        df.to_excel(ruta_excel, index=False)

        print(f"Métricas de '{ruta_csv}' guardadas exitosamente en: {ruta_excel}")
        return True

    except Exception as e:
        print(f"Error durante la conversión de '{ruta_csv}' a Excel: {e}")
        return False

# %%
from google.colab import files

# Lista de los archivos CSV de registro que se generaron
archivos_csv_registros = [
    'registro_entrenamiento_modelo_1_normal.csv',
    'registro_entrenamiento_modelo_1_opt.csv',
    'registro_entrenamiento_modelo_1_cplana.csv',
    'registro_entrenamiento_modelo_2.csv',
    'registro_entrenamiento_modelo_3.csv',
    'registro_entrenamiento_modelo_4.csv',
    'log_model_TL.csv'
]

# Carpeta para guardar los archivos Excel
carpeta_excel = '/content/Metricas_Excel/'
os.makedirs(carpeta_excel, exist_ok=True)

print("--- Iniciando conversión y descarga de métricas ---")
for nombre_csv in archivos_csv_registros:
    nombre_excel = nombre_csv.replace('.csv', '.xlsx')
    ruta_excel_destino = os.path.join(carpeta_excel, nombre_excel)

    # Intentar convertir el archivo
    if convertir_csv_a_excel(nombre_csv, ruta_excel_destino):
        # Si la conversión fue exitosa, descargar el archivo
        print(f"Iniciando descarga de {ruta_excel_destino}...")
        files.download(ruta_excel_destino)

print("\n--- Proceso de conversión y descarga finalizado. ---")
# Out:
# --- Iniciando conversión y descarga de métricas ---
# Advertencia: El archivo CSV no fue encontrado en la ruta: registro_entrenamiento_modelo_1_normal.csv
# Advertencia: El archivo CSV no fue encontrado en la ruta: registro_entrenamiento_modelo_1_opt.csv
# Advertencia: El archivo CSV no fue encontrado en la ruta: registro_entrenamiento_modelo_1_cplana.csv
# Advertencia: El archivo CSV no fue encontrado en la ruta: registro_entrenamiento_modelo_2.csv
# Advertencia: El archivo CSV no fue encontrado en la ruta: registro_entrenamiento_modelo_3.csv
# Métricas de 'registro_entrenamiento_modelo_4.csv' guardadas exitosamente en: /content/Metricas_Excel/registro_entrenamiento_modelo_4.xlsx
# Iniciando descarga de /content/Metricas_Excel/registro_entrenamiento_modelo_4.xlsx...
# Métricas de 'log_model_TL.csv' guardadas exitosamente en: /content/Metricas_Excel/log_model_TL.xlsx
# Iniciando descarga de /content/Metricas_Excel/log_model_TL.xlsx...
# --- Proceso de conversión y descarga finalizado. ---

# %%
import os

# Crear la carpeta para guardar los modelos si no existe
os.makedirs('/content/MisModelos', exist_ok=True)

# Guardar los modelos entrenados
print("Guardando modelos...")
Modelo_1_Normal_Refac.save('/content/MisModelos/Modelo_1_Normal.h5')
Modelo_1_Optimizado_Refac.save('/content/MisModelos/Modelo_1_Optimizado.h5')
Modelo_1_CapaPlana_Refac.save('/content/MisModelos/Modelo_1_CapaPlana.h5')
Modelo_2_Refac.save('/content/MisModelos/Modelo_2.h5')
Modelo_3_Refac.save('/content/MisModelos/Modelo_3.h5')
Modelo_4_Refac.save('/content/MisModelos/Modelo_4.h5')

print("Modelos guardados exitosamente en /content/MisModelos/")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Guardando modelos...
# Modelos guardados exitosamente en /content/MisModelos/
